# %%
# STEP 1: ENV SETUP
# !pip install -q opencv-python-headless scikit-learn

import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models, backend as K

# Set image size
IMG_SIZE = 128
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 1)

# Check GPU
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# STEP 2: SETUP KAGGLE API
import os
import zipfile

# Upload your kaggle.json file
from google.colab import files
files.upload()

# Move kaggle.json to correct location
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download BUSI dataset
# !kaggle datasets download -d aryashah2k/breast-ultrasound-images-dataset

# Unzip it
with zipfile.ZipFile("breast-ultrasound-images-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("BUSI")
# Out:
#      <input type="file" id="files-518e3420-e872-49d6-8717-8df31f371942" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-518e3420-e872-49d6-8717-8df31f371942">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_path = "/content/breast-ultrasound-images-dataset.zip"
extract_path = "/content/BUSI"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Unzipped to:", extract_path)
# Out:
# ✅ Unzipped to: /content/BUSI

# %%
# !ls /content/BUSI/Dataset_BUSI_with_GT/
# Out:
# benign	malignant  normal

# %%
def load_busi_dataset(base_path="/content/BUSI/Dataset_BUSI_with_GT", img_size=128):
    import glob
    import cv2
    import numpy as np
    import os

    images, masks = [], []
    for cls in ["benign", "malignant", "normal"]:
        folder = os.path.join(base_path, cls)
        all_images = glob.glob(os.path.join(folder, "*.png"))
        print(f"[{cls}] Found {len(all_images)} PNG files in {folder}")

        for img_path in all_images:
            if "_mask" in img_path:
                continue

            mask_path = img_path.replace(".png", "_mask.png")
            if not os.path.exists(mask_path):
                continue

            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

            if img is None or mask is None:
                print(f"❌ Could not load: {img_path}")
                continue

            img = cv2.resize(img, (img_size, img_size))
            mask = cv2.resize(mask, (img_size, img_size))

            img = img.astype(np.float32) / 255.0
            mask = (mask > 127).astype(np.float32)

            images.append(np.expand_dims(img, axis=-1))
            masks.append(np.expand_dims(mask, axis=-1))

    images = np.array(images)
    masks = np.array(masks)
    print(f"✅ Loaded {len(images)} valid image-mask pairs.")
    return images, masks

# %%
X, Y = load_busi_dataset("/content/BUSI/Dataset_BUSI_with_GT")
from sklearn.model_selection import train_test_split
X_train, X_temp, Y_train, Y_temp = train_test_split(X, Y, test_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp, test_size=2/3, random_state=42)

print("Train:", X_train.shape)
print("Val:", X_val.shape)
print("Test:", X_test.shape)
# Out:
# [benign] Found 891 PNG files in /content/BUSI/Dataset_BUSI_with_GT/benign
# [malignant] Found 421 PNG files in /content/BUSI/Dataset_BUSI_with_GT/malignant
# [normal] Found 266 PNG files in /content/BUSI/Dataset_BUSI_with_GT/normal
# ✅ Loaded 780 valid image-mask pairs.
# Train: (546, 128, 128, 1)
# Val: (78, 128, 128, 1)
# Test: (156, 128, 128, 1)

# %%
def conv_block(x, filters):
    shortcut = x
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization()(x)

    # Residual connection
    shortcut = layers.Conv2D(filters, 1, padding="same")(shortcut)
    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)
    return x

def encoder_block(x, filters):
    x = conv_block(x, filters)
    p = layers.MaxPooling2D((2, 2))(x)
    return x, p

def decoder_block(x, skip, filters):
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

# %%
def cbam_block(x, reduction=8):
    # Channel attention
    channel = x.shape[-1]
    avg_pool = layers.GlobalAveragePooling2D()(x)
    max_pool = layers.GlobalMaxPooling2D()(x)

    dense_shared_1 = layers.Dense(channel // reduction, activation='relu')
    dense_shared_2 = layers.Dense(channel, activation='sigmoid')

    avg_out = dense_shared_2(dense_shared_1(avg_pool))
    max_out = dense_shared_2(dense_shared_1(max_pool))
    channel_attention = layers.Add()([avg_out, max_out])
    channel_attention = layers.Reshape((1, 1, channel))(channel_attention)
    x = layers.Multiply()([x, channel_attention])

    # Spatial attention using only Keras
    avg_pool = layers.Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(x)
    max_pool = layers.Lambda(lambda x: K.max(x, axis=3, keepdims=True))(x)
    concat = layers.Concatenate(axis=-1)([avg_pool, max_pool])
    spatial_attention = layers.Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    x = layers.Multiply()([x, spatial_attention])
    return x

def pam_block(x):
    shape = x.shape
    reshaped = layers.Reshape((-1, shape[-1]))(x)  # (batch, H*W, C)

    attention = layers.Dot(axes=-1)([reshaped, reshaped])  # (batch, H*W, H*W)
    attention = layers.Softmax()(attention)

    attended = layers.Dot(axes=(2, 1))([attention, reshaped])  # (batch, H*W, C)
    out = layers.Reshape((shape[1], shape[2], shape[-1]))(attended)
    return layers.Add()([x, out])

# %%
def swa_block(x):
    c = x.shape[-1]
    q = layers.Conv2D(c, 1)(x)
    k = layers.Conv2D(c, 1)(x)
    v = layers.Conv2D(c, 1)(x)

    q_ = layers.Reshape((-1, c))(q)
    k_ = layers.Reshape((-1, c))(k)
    v_ = layers.Reshape((-1, c))(v)

    attention = layers.Dot(axes=(2, 2))([q_, k_])
    attention = layers.Softmax()(attention)

    context = layers.Dot(axes=(2, 1))([attention, v_])
    context = layers.Reshape((x.shape[1], x.shape[2], c))(context)
    return layers.Add()([x, context])

# %%
def pcbam_block(x):
    cbam = cbam_block(x)
    pam = pam_block(x)
    return layers.Add()([cbam, pam])

# %%
def build_dau_net(input_shape=(128,128,1)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)

    # Bottleneck with SWA
    b = conv_block(p3, 256)
    b = swa_block(b)

    # Decoder with PCBAM
    d3 = decoder_block(b, pcbam_block(s3), 128)
    d2 = decoder_block(d3, pcbam_block(s2), 64)
    d1 = decoder_block(d2, pcbam_block(s1), 32)

    # Output
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(d1)

    return models.Model(inputs, outputs)

# %%
model = build_dau_net()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │        320 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return 1 - ((2. * intersection + smooth) /
                (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    d_loss = dice_loss(y_true, y_pred)
    return bce + d_loss

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
              loss=bce_dice_loss,
              metrics=["accuracy"])

# %%
history = model.fit(X_train, Y_train,
                    validation_data=(X_val, Y_val),
                    epochs=10,
                    batch_size=2)
# Out:
# Epoch 1/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 85s 225ms/step - accuracy: 0.8983 - loss: 1.1674 - val_accuracy: 0.9299 - val_loss: 1.0833
# Epoch 2/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 114s 210ms/step - accuracy: 0.9316 - loss: 0.7956 - val_accuracy: 0.8672 - val_loss: 1.0221
# Epoch 3/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 0.9477 - loss: 0.6810 - val_accuracy: 0.9401 - val_loss: 0.8141
# Epoch 4/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 84s 218ms/step - accuracy: 0.9455 - loss: 0.6235 - val_accuracy: 0.9422 - val_loss: 0.8191
# Epoch 5/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - accuracy: 0.9539 - loss: 0.5654 - val_accuracy: 0.9459 - val_loss: 0.7027
# Epoch 6/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 80s 210ms/step - accuracy: 0.9578 - loss: 0.5175 - val_accuracy: 0.9425 - val_loss: 0.6453
# Epoch 7/10
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 84s 218ms/step - accuracy: 0.9633 - loss: 0.4612 - val_accuracy: 0.9359 - val_loss: 0.7046
# Epoch 8/10
# ...

# %%
results = model.evaluate(X_test, Y_test, batch_size=1)
print(f" Test Loss: {results[0]:.4f}")
print(f" Test Accuracy: {results[1]*100:.2f}%")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - accuracy: 0.9435 - loss: 0.7717
#  Test Loss: 0.8090
#  Test Accuracy: 93.67%

# %%
import matplotlib.pyplot as plt

num_samples = 5
for i in range(num_samples):
    idx = np.random.randint(0, len(X_test))
    img = X_test[idx]
    mask = Y_test[idx]
    pred = model.predict(img[np.newaxis, ...])[0] > 0.5

    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.title("Input")
    plt.imshow(img.squeeze(), cmap='gray')

    plt.subplot(1, 3, 2)
    plt.title("Ground Truth")
    plt.imshow(mask.squeeze(), cmap='gray')

    plt.subplot(1, 3, 3)
    plt.title("Prediction")
    plt.imshow(pred.squeeze(), cmap='gray')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
model.save("dau_net_busi.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
